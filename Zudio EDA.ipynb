# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
df = pd.read_csv("C:/Users/Pragya Prasad/Downloads/Zudio_sales_data.csv")
print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
df.head()
# Out:
#    Store Country          State      City Category Clothing Type  \
# 0  Zudio   India      Karnataka     Jalna    Women       Dresses
# 1  Zudio   India        Gujarat     Patna     Kids        Skirts
# 2  Zudio   India  Uttar Pradesh   Kolkata      Men       Hoodies
# 3  Zudio   India    West Bengal   Kolkata    Women       Dresses
# 4  Zudio   India    West Bengal  Guwahati      Men       Dresses
#
#    Store Number  Postal Code Store Type Store Open Date  \
# 0            30       411084      Owned      2022-06-04
# 1            48       404562      Owned      2020-12-19
# 2            97       437773     Rented      2023-09-04
# 3            93       431725      Owned      2024-04-11
# 4            51       415370      Owned      2022-05-29
#
#    Selling Area Size (sq ft)    Store Manager Manager ID  \
# 0                        950        Lori Hill        M77
# 1                       1200  Deborah Jackson        M89
# 2                       1100    Adam Anderson        M71
# ...

# %%
print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])
# Out:
# Number of Rows: 7899
# Number of Columns: 28

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7899 entries, 0 to 7898
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      7899 non-null   str
#  1   Country                    7899 non-null   str
#  2   State                      7899 non-null   str
#  3   City                       7899 non-null   str
#  4   Category                   7899 non-null   str
#  5   Clothing Type              7899 non-null   str
#  6   Store Number               7899 non-null   int64
#  7   Postal Code                7899 non-null   int64
#  8   Store Type                 7899 non-null   str
#  9   Store Open Date            7899 non-null   str
#  10  Selling Area Size (sq ft)  7899 non-null   int64
#  11  Store Manager              7899 non-null   str
#  12  Manager ID                 7899 non-null   str
#  13  Store Address              7899 non-null   str
# ...

# %%
df.describe()
# Out:
#        Store Number    Postal Code  Selling Area Size (sq ft)  Staff Count  \
# count   7899.000000    7899.000000                7899.000000  7899.000000
# mean      50.666034  419982.374984                1112.077478    11.504747
# std       29.095274   11695.237817                 193.239371     5.194722
# min        1.000000  400006.000000                 800.000000     3.000000
# 25%       25.000000  409841.000000                 950.000000     7.000000
# 50%       51.000000  419988.000000                1100.000000    12.000000
# 75%       76.000000  430258.000000                1300.000000    16.000000
# max      100.000000  439985.000000                1400.000000    20.000000
#
#            Order ID    Customer ID   Product ID        Price     Quantity  \
# count   7899.000000    7899.000000  7899.000000  7899.000000  7899.000000
# mean   54920.719965  549440.714521   602.069376  1761.113432     4.519433
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Store', 'Country', 'State', 'City', 'Category', 'Clothing Type', 'Store Number', 'Postal Code', 'Store Type', 'Store Open Date', 'Selling Area Size (sq ft)', 'Store Manager', 'Manager ID', 'Store Address', 'Contact Information', 'Operating Hours', 'Staff Count', 'Parking Availability', 'Security Features', 'Order ID', 'Order Date', 'Month', 'Customer ID', 'Customer Name', 'Product ID', 'Price', 'Quantity', 'Sales Profit']

# %%
missing_values = df.isnull().sum()

missing_values = missing_values[missing_values > 0].sort_values(ascending=False)

print("Columns containing missing values:")
print(missing_values)
# Out:
# Columns containing missing values:
# Security Features    2038
# dtype: int64

# %%
missing_percentage = (df.isnull().sum() / len(df) * 100).sort_values(ascending=False)

missing_percentage[missing_percentage > 0]
# Out:
# Security Features    25.800734
# dtype: float64

# %%
duplicate_count = df.duplicated().sum()

print("Number of duplicate rows:", duplicate_count)
# Out:
# Number of duplicate rows: 0

# %%
df.dtypes
# Out:
# Store                            str
# Country                          str
# State                            str
# City                             str
# Category                         str
# Clothing Type                    str
# Store Number                   int64
# Postal Code                    int64
# Store Type                       str
# Store Open Date                  str
# Selling Area Size (sq ft)      int64
# Store Manager                    str
# Manager ID                       str
# Store Address                    str
# Contact Information              str
# Operating Hours                  str
# Staff Count                    int64
# Parking Availability             str
# Security Features                str
# Order ID                       int64
# Order Date                       str
# Month                            str
# Customer ID                    int64
# Customer Name                    str
# Product ID                     int64
# ...

# %%
df['Store Open Date'] = pd.to_datetime(
    df['Store Open Date'],
    errors='coerce'
)

df['Order Date'] = pd.to_datetime(
    df['Order Date'],
    errors='coerce'
)

# %%
df[['Store Open Date', 'Order Date']].head()
# Out:
#   Store Open Date Order Date
# 0      2022-06-04 2024-11-06
# 1      2020-12-19 2024-06-17
# 2      2023-09-04 2024-08-17
# 3      2024-04-11 2024-03-27
# 4      2022-05-29 2024-04-08

# %%
numeric_columns = [
    'Selling Area Size (sq ft)',
    'Staff Count',
    'Order ID',
    'Customer ID',
    'Product ID',
    'Price',
    'Quantity',
    'Sales Profit'
]

df[numeric_columns].describe().T
# Out:
#                             count           mean            std       min  \
# Selling Area Size (sq ft)  7899.0    1112.077478     193.239371     800.0
# Staff Count                7899.0      11.504747       5.194722       3.0
# Order ID                   7899.0   54920.719965   25894.206850   10008.0
# Customer ID                7899.0  549440.714521  262418.912565  100153.0
# Product ID                 7899.0     602.069376     232.066189     204.0
# Price                      7899.0    1761.113432     716.269447     499.0
# Quantity                   7899.0       4.519433       2.292373       1.0
# Sales Profit               7899.0    3170.671376    2141.249886     200.4
#
#                                 25%       50%       75%       max
# Selling Area Size (sq ft)     950.0    1100.0    1300.0    1400.0
# Staff Count                     7.0      12.0      16.0      20.0
# Order ID                    33192.0   54873.0   77285.0   99999.0
# ...

# %%
print("Categories:")
print(df['Category'].value_counts())
# Out:
# Categories:
# Category
# Kids     2673
# Men      2643
# Women    2583
# Name: count, dtype: int64

# %%
print("Clothing Types:")
print(df['Clothing Type'].value_counts())
# Out:
# Clothing Types:
# Clothing Type
# Dresses     748
# Jackets     735
# T-shirts    735
# Skirts      726
# Tops        722
# Pants       721
# Shirts      706
# Hoodies     704
# Jeans       702
# Shoes       700
# Sweaters    700
# Name: count, dtype: int64

# %%
print("Store Types:")
print(df['Store Type'].value_counts())
# Out:
# Store Types:
# Store Type
# Rented    3974
# Owned     3925
# Name: count, dtype: int64

# %%
print("Store Types:")
print(df['Store Type'].value_counts())
# Out:
# Store Types:
# Store Type
# Rented    3974
# Owned     3925
# Name: count, dtype: int64

# %%
df['State'].value_counts().head(15)
# Out:
# State
# Rajasthan        1013
# Uttar Pradesh    1011
# Delhi            1011
# Gujarat           982
# West Bengal       982
# Maharashtra       975
# Karnataka         963
# Tamil Nadu        962
# Name: count, dtype: int64

# %%
df['City'].value_counts().head(15)
# Out:
# City
# Kolkata       210
# Mysuru        207
# New Delhi     205
# Madurai       204
# Jammu         204
# Bhopal        203
# Rajkot        202
# Hyderabad     201
# Indore        200
# Pune          200
# Jalna         199
# Coimbatore    199
# Ahmedabad     195
# Bengaluru     194
# Noida         193
# Name: count, dtype: int64

# %%
total_quantity = df['Quantity'].sum()

print("Total Quantity Sold:", total_quantity)
# Out:
# Total Quantity Sold: 35699

# %%
average_price = df['Price'].mean()

print("Average Price:", round(average_price, 2))
# Out:
# Average Price: 1761.11

# %%
df['Sales'] = df['Price'] * df['Quantity']

# %%
total_sales = df['Sales'].sum()

print("Total Sales:", round(total_sales, 2))
# Out:
# Total Sales: 62612833

# %%
total_profit = df['Sales Profit'].sum()

print("Total Sales Profit:", round(total_profit, 2))
# Out:
# Total Sales Profit: 25045133.2

# %%
profit_margin = (total_profit / total_sales) * 100

print("Profit Margin:", round(profit_margin, 2), "%")
# Out:
# Profit Margin: 40.0 %

# %%
kpi_summary = pd.DataFrame({
    'KPI': [
        'Total Sales',
        'Total Profit',
        'Total Quantity Sold',
        'Average Price',
        'Profit Margin'
    ],
    'Value': [
        total_sales,
        total_profit,
        total_quantity,
        average_price,
        profit_margin
    ]
})

kpi_summary
# Out:
#                    KPI         Value
# 0          Total Sales  6.261283e+07
# 1         Total Profit  2.504513e+07
# 2  Total Quantity Sold  3.569900e+04
# 3        Average Price  1.761113e+03
# 4        Profit Margin  4.000000e+01

# %%
df['Price'].describe()
# Out:
# count    7899.000000
# mean     1761.113432
# std       716.269447
# min       499.000000
# 25%      1136.000000
# 50%      1782.000000
# 75%      2373.000000
# max      2999.000000
# Name: Price, dtype: float64

# %%
df['Quantity'].describe()
# Out:
# count    7899.000000
# mean        4.519433
# std         2.292373
# min         1.000000
# 25%         3.000000
# 50%         5.000000
# 75%         7.000000
# max         8.000000
# Name: Quantity, dtype: float64

# %%
df['Sales'].describe()
# Out:
# count     7899.000000
# mean      7926.678440
# std       5353.124714
# min        501.000000
# 25%       3528.000000
# 50%       6704.000000
# 75%      11426.000000
# max      23992.000000
# Name: Sales, dtype: float64

# %%
df['Sales Profit'].describe()
# Out:
# count    7899.000000
# mean     3170.671376
# std      2141.249886
# min       200.400000
# 25%      1411.200000
# 50%      2681.600000
# 75%      4570.400000
# max      9596.800000
# Name: Sales Profit, dtype: float64

# %%
df['Profit Margin %'] = (
    df['Sales Profit'] / df['Sales']
) * 100

df['Profit Margin %'].describe()
# Out:
# count    7.899000e+03
# mean     4.000000e+01
# std      1.646321e-15
# min      4.000000e+01
# 25%      4.000000e+01
# 50%      4.000000e+01
# 75%      4.000000e+01
# max      4.000000e+01
# Name: Profit Margin %, dtype: float64

# %%
df[['Sales', 'Sales Profit', 'Profit Margin %']].head(10)
# Out:
#    Sales  Sales Profit  Profit Margin %
# 0   9790        3916.0             40.0
# 1   2078         831.2             40.0
# 2   2890        1156.0             40.0
# 3  14814        5925.6             40.0
# 4   6630        2652.0             40.0
# 5   8824        3529.6             40.0
# 6  11392        4556.8             40.0
# 7  13552        5420.8             40.0
# 8   2024         809.6             40.0
# 9  15486        6194.4             40.0

# %%
df['Profit Margin %'].round(2).value_counts().head(20)
# Out:
# Profit Margin %
# 40.0    7899
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))

sns.histplot(
    data=df,
    x='Price',
    bins=30,
    kde=True
)

plt.title('Distribution of Product Prices')
plt.xlabel('Price (₹)')
plt.ylabel('Number of Transactions')

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.countplot(
    data=df,
    x='Quantity'
)

plt.title('Distribution of Quantity Sold per Transaction')
plt.xlabel('Quantity')
plt.ylabel('Number of Transactions')

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.histplot(
    data=df,
    x='Sales',
    bins=30,
    kde=True
)

plt.title('Distribution of Sales')
plt.xlabel('Sales (₹)')
plt.ylabel('Frequency')

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.histplot(
    data=df,
    x='Sales Profit',
    bins=30,
    kde=True
)

plt.title('Distribution of Sales Profit')
plt.xlabel('Sales Profit (₹)')
plt.ylabel('Frequency')

plt.show()

# %%
category_sales = (
    df.groupby('Category')['Sales']
    .sum()
    .sort_values(ascending=False)
)

print(category_sales)
# Out:
# Category
# Kids     21104267
# Women    20982174
# Men      20526392
# Name: Sales, dtype: int64

# %%
plt.figure(figsize=(10, 6))

category_sales.plot(kind='bar')

plt.title('Total Sales by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Total Sales (₹)')
plt.xticks(rotation=45)

plt.show()

# %%
category_profit = (
    df.groupby('Category')['Sales Profit']
    .sum()
    .sort_values(ascending=False)
)

print(category_profit)
# Out:
# Category
# Kids     8441706.8
# Women    8392869.6
# Men      8210556.8
# Name: Sales Profit, dtype: float64

# %%
plt.figure(figsize=(10, 6))

category_profit.plot(kind='bar')

plt.title('Total Profit by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Total Profit (₹)')
plt.xticks(rotation=45)

plt.show()

# %%
category_analysis = df.groupby('Category').agg(
    Total_Sales=('Sales', 'sum'),
    Total_Profit=('Sales Profit', 'sum'),
    Units_Sold=('Quantity', 'sum'),
    Average_Price=('Price', 'mean'),
    Transactions=('Order ID', 'count')
).reset_index()

category_analysis['Profit_Margin_%'] = (
    category_analysis['Total_Profit'] /
    category_analysis['Total_Sales']
) * 100

category_analysis = category_analysis.sort_values(
    'Total_Sales',
    ascending=False
)

category_analysis
# Out:
#   Category  Total_Sales  Total_Profit  Units_Sold  Average_Price  \
# 0     Kids     21104267     8441706.8       12013    1761.121960
# 2    Women     20982174     8392869.6       11959    1758.424313
# 1      Men     20526392     8210556.8       11727    1763.732879
#
#    Transactions  Profit_Margin_%
# 0          2673             40.0
# 2          2583             40.0
# 1          2643             40.0

# %%
print("Number of unique products:", df['Product ID'].nunique())
# Out:
# Number of unique products: 796

# %%
product_analysis = df.groupby('Product ID').agg(
    Total_Sales=('Sales', 'sum'),
    Total_Profit=('Sales Profit', 'sum'),
    Units_Sold=('Quantity', 'sum'),
    Transactions=('Order ID', 'count'),
    Average_Price=('Price', 'mean')
).reset_index()

product_analysis['Profit_Margin_%'] = (
    product_analysis['Total_Profit'] /
    product_analysis['Total_Sales']
) * 100

# %%
top_10_sales = product_analysis.sort_values(
    'Total_Sales',
    ascending=False
).head(10)

top_10_sales
# Out:
#      Product ID  Total_Sales  Total_Profit  Units_Sold  Transactions  \
# 425         629       175886       70354.4          91            19
# 794         998       175037       70014.8          79            16
# 759         963       172832       69132.8          87            19
# 536         740       169570       67828.0          92            17
# 277         481       169517       67806.8          84            18
# 210         414       167187       66874.8          87            21
# 514         718       164676       65870.4          80            16
# 520         724       160341       64136.4          75            15
# 766         970       156406       62562.4         102            22
# 54          258       152863       61145.2          99            22
#
#      Average_Price  Profit_Margin_%
# 425    1909.578947             40.0
# 794    2128.187500             40.0
# 759    2001.526316             40.0
# 536    1932.588235             40.0
# ...

# %%
plt.figure(figsize=(12, 6))

sns.barplot(
    data=top_10_sales,
    x='Total_Sales',
    y='Product ID'
)

plt.title('Top 10 Products by Sales')
plt.xlabel('Total Sales (₹)')
plt.ylabel('Product ID')

plt.show()

# %%
bottom_10_sales = product_analysis.sort_values(
    'Total_Sales',
    ascending=True
).head(10)

bottom_10_sales
# Out:
#      Product ID  Total_Sales  Total_Profit  Units_Sold  Transactions  \
# 605         809        11036        4414.4           6             2
# 378         582        11438        4575.2           8             4
# 774         978        11759        4703.6           7             4
# 235         439        12296        4918.4           8             6
# 462         666        13311        5324.4           6             2
# 482         686        13424        5369.6          14             3
# 454         658        13759        5503.6          11             5
# 53          257        17649        7059.6          14             5
# 763         967        17665        7066.0           9             5
# 742         946        18917        7566.8          14             5
#
#      Average_Price  Profit_Margin_%
# 605    2023.500000             40.0
# 378    1692.250000             40.0
# 774    1533.000000             40.0
# 235    1679.333333             40.0
# ...

# %%
plt.figure(figsize=(12, 6))

sns.barplot(
    data=bottom_10_sales,
    x='Total_Sales',
    y='Product ID'
)

plt.title('Bottom 10 Products by Sales')
plt.xlabel('Total Sales (₹)')
plt.ylabel('Product ID')

plt.show()

# %%
top_10_profit = product_analysis.sort_values(
    'Total_Profit',
    ascending=False
).head(10)

top_10_profit
# Out:
#      Product ID  Total_Sales  Total_Profit  Units_Sold  Transactions  \
# 425         629       175886       70354.4          91            19
# 794         998       175037       70014.8          79            16
# 759         963       172832       69132.8          87            19
# 536         740       169570       67828.0          92            17
# 277         481       169517       67806.8          84            18
# 210         414       167187       66874.8          87            21
# 514         718       164676       65870.4          80            16
# 520         724       160341       64136.4          75            15
# 766         970       156406       62562.4         102            22
# 54          258       152863       61145.2          99            22
#
#      Average_Price  Profit_Margin_%
# 425    1909.578947             40.0
# 794    2128.187500             40.0
# 759    2001.526316             40.0
# 536    1932.588235             40.0
# ...

# %%
plt.figure(figsize=(12, 6))

sns.barplot(
    data=top_10_profit,
    x='Total_Profit',
    y='Product ID'
)

plt.title('Top 10 Products by Profit')
plt.xlabel('Total Profit (₹)')
plt.ylabel('Product ID')

plt.show()

# %%
state_analysis = df.groupby('State').agg(
    Total_Sales=('Sales', 'sum'),
    Total_Profit=('Sales Profit', 'sum'),
    Units_Sold=('Quantity', 'sum'),
    Transactions=('Order ID', 'count'),
    Average_Price=('Price', 'mean')
).reset_index()

state_analysis['Profit_Margin_%'] = (
    state_analysis['Total_Profit'] /
    state_analysis['Total_Sales']
) * 100

state_analysis = state_analysis.sort_values(
    'Total_Sales',
    ascending=False
)

state_analysis
# Out:
#            State  Total_Sales  Total_Profit  Units_Sold  Transactions  \
# 7    West Bengal      8105787     3242314.8        4529           982
# 0          Delhi      7978289     3191315.6        4599          1011
# 4      Rajasthan      7969779     3187911.6        4451          1013
# 6  Uttar Pradesh      7907535     3163014.0        4499          1011
# 3    Maharashtra      7724214     3089685.6        4546           975
# 5     Tamil Nadu      7714058     3085623.2        4334           962
# 1        Gujarat      7626302     3050520.8        4414           982
# 2      Karnataka      7586869     3034747.6        4327           963
#
#    Average_Price  Profit_Margin_%
# 7    1794.789206             40.0
# 0    1739.807122             40.0
# 4    1780.213228             40.0
# 6    1765.800198             40.0
# 3    1733.133333             40.0
# 5    1772.522869             40.0
# 1    1747.853360             40.0
# 2    1754.582555             40.0

# %%
top_states = state_analysis.head(10)

top_states
# Out:
#            State  Total_Sales  Total_Profit  Units_Sold  Transactions  \
# 7    West Bengal      8105787     3242314.8        4529           982
# 0          Delhi      7978289     3191315.6        4599          1011
# 4      Rajasthan      7969779     3187911.6        4451          1013
# 6  Uttar Pradesh      7907535     3163014.0        4499          1011
# 3    Maharashtra      7724214     3089685.6        4546           975
# 5     Tamil Nadu      7714058     3085623.2        4334           962
# 1        Gujarat      7626302     3050520.8        4414           982
# 2      Karnataka      7586869     3034747.6        4327           963
#
#    Average_Price  Profit_Margin_%
# 7    1794.789206             40.0
# 0    1739.807122             40.0
# 4    1780.213228             40.0
# 6    1765.800198             40.0
# 3    1733.133333             40.0
# 5    1772.522869             40.0
# 1    1747.853360             40.0
# 2    1754.582555             40.0

# %%
plt.figure(figsize=(12, 6))

sns.barplot(
    data=top_states,
    x='Total_Sales',
    y='State'
)

plt.title('Top 10 States by Total Sales')
plt.xlabel('Total Sales (₹)')
plt.ylabel('State')

plt.show()

# %%
top_profit_states = state_analysis.sort_values(
    'Total_Profit',
    ascending=False
).head(10)

top_profit_states
# Out:
#            State  Total_Sales  Total_Profit  Units_Sold  Transactions  \
# 7    West Bengal      8105787     3242314.8        4529           982
# 0          Delhi      7978289     3191315.6        4599          1011
# 4      Rajasthan      7969779     3187911.6        4451          1013
# 6  Uttar Pradesh      7907535     3163014.0        4499          1011
# 3    Maharashtra      7724214     3089685.6        4546           975
# 5     Tamil Nadu      7714058     3085623.2        4334           962
# 1        Gujarat      7626302     3050520.8        4414           982
# 2      Karnataka      7586869     3034747.6        4327           963
#
#    Average_Price  Profit_Margin_%
# 7    1794.789206             40.0
# 0    1739.807122             40.0
# 4    1780.213228             40.0
# 6    1765.800198             40.0
# 3    1733.133333             40.0
# 5    1772.522869             40.0
# 1    1747.853360             40.0
# 2    1754.582555             40.0

# %%
plt.figure(figsize=(12, 6))

sns.barplot(
    data=top_profit_states,
    x='Total_Profit',
    y='State'
)

plt.title('Top 10 States by Total Profit')
plt.xlabel('Total Profit (₹)')
plt.ylabel('State')

plt.show()

# %%
city_analysis = df.groupby('City').agg(
    Total_Sales=('Sales', 'sum'),
    Total_Profit=('Sales Profit', 'sum'),
    Units_Sold=('Quantity', 'sum'),
    Transactions=('Order ID', 'count'),
    Average_Price=('Price', 'mean')
).reset_index()

city_analysis['Profit_Margin_%'] = (
    city_analysis['Total_Profit'] /
    city_analysis['Total_Sales']
) * 100

city_analysis = city_analysis.sort_values(
    'Total_Sales',
    ascending=False
)

city_analysis.head(10)
# Out:
#              City  Total_Sales  Total_Profit  Units_Sold  Transactions  \
# 15          Jalna      1719676      687870.4         975           199
# 25         Mysuru      1703579      681431.6         932           207
# 16          Jammu      1664596      665838.4         921           204
# 20        Kolkata      1645961      658384.4         968           210
# 4          Bhopal      1645597      658238.8         921           203
# 12      Hyderabad      1642797      657118.8         940           201
# 8      Coimbatore      1629608      651843.2         896           199
# 0            Agra      1603054      641221.6         879           187
# 41  Visakhapatnam      1594813      637925.2         894           193
# 13         Indore      1590816      636326.4         896           200
#
#     Average_Price  Profit_Margin_%
# 15    1740.698492             40.0
# 25    1797.859903             40.0
# 16    1857.279412             40.0
# 20    1735.323810             40.0
# ...

# %%
plt.figure(figsize=(12, 6))

sns.barplot(
    data=city_analysis.head(10),
    x='Total_Sales',
    y='City'
)

plt.title('Top 10 Cities by Total Sales')
plt.xlabel('Total Sales (₹)')
plt.ylabel('City')

plt.show()

# %%
print("Minimum Order Date:", df['Order Date'].min())
print("Maximum Order Date:", df['Order Date'].max())
# Out:
# Minimum Order Date: 2024-01-01 00:00:00
# Maximum Order Date: 2024-12-03 00:00:00

# %%
df['Year_Month'] = df['Order Date'].dt.to_period('M').astype(str)

# %%
monthly_sales = df.groupby('Year_Month').agg(
    Total_Sales=('Sales', 'sum'),
    Total_Profit=('Sales Profit', 'sum'),
    Units_Sold=('Quantity', 'sum'),
    Transactions=('Order ID', 'count')
).reset_index()

monthly_sales
# Out:
#    Year_Month  Total_Sales  Total_Profit  Units_Sold  Transactions
# 0     2024-01      5761931     2304772.4        3222           706
# 1     2024-02      5444087     2177634.8        3097           689
# 2     2024-03      5652839     2261135.6        3295           733
# 3     2024-04      5661436     2264574.4        3358           719
# 4     2024-05      5612938     2245175.2        3174           721
# 5     2024-06      5425085     2170034.0        3144           695
# 6     2024-07      5530078     2212031.2        3195           697
# 7     2024-08      5796433     2318573.2        3260           724
# 8     2024-09      5431190     2172476.0        3089           659
# 9     2024-10      5930474     2372189.6        3308           743
# 10    2024-11      5782246     2312898.4        3214           729
# 11    2024-12       584096      233638.4         343            84

# %%
city_analysis.head(10)
# Out:
#              City  Total_Sales  Total_Profit  Units_Sold  Transactions  \
# 15          Jalna      1719676      687870.4         975           199
# 25         Mysuru      1703579      681431.6         932           207
# 16          Jammu      1664596      665838.4         921           204
# 20        Kolkata      1645961      658384.4         968           210
# 4          Bhopal      1645597      658238.8         921           203
# 12      Hyderabad      1642797      657118.8         940           201
# 8      Coimbatore      1629608      651843.2         896           199
# 0            Agra      1603054      641221.6         879           187
# 41  Visakhapatnam      1594813      637925.2         894           193
# 13         Indore      1590816      636326.4         896           200
#
#     Average_Price  Profit_Margin_%
# 15    1740.698492             40.0
# 25    1797.859903             40.0
# 16    1857.279412             40.0
# 20    1735.323810             40.0
# ...

# %%
monthly_sales
# Out:
#    Year_Month  Total_Sales  Total_Profit  Units_Sold  Transactions
# 0     2024-01      5761931     2304772.4        3222           706
# 1     2024-02      5444087     2177634.8        3097           689
# 2     2024-03      5652839     2261135.6        3295           733
# 3     2024-04      5661436     2264574.4        3358           719
# 4     2024-05      5612938     2245175.2        3174           721
# 5     2024-06      5425085     2170034.0        3144           695
# 6     2024-07      5530078     2212031.2        3195           697
# 7     2024-08      5796433     2318573.2        3260           724
# 8     2024-09      5431190     2172476.0        3089           659
# 9     2024-10      5930474     2372189.6        3308           743
# 10    2024-11      5782246     2312898.4        3214           729
# 11    2024-12       584096      233638.4         343            84

# %%
df[df['Order Date'].dt.month == 12]['Order Date'].describe()
# Out:
# count                            84
# mean     2024-12-02 00:17:08.571428
# min             2024-12-01 00:00:00
# 25%             2024-12-01 00:00:00
# 50%             2024-12-02 00:00:00
# 75%             2024-12-03 00:00:00
# max             2024-12-03 00:00:00
# Name: Order Date, dtype: object

# %%
december_data = df[df['Order Date'].dt.month == 12]

print("December transactions:", len(december_data))
print("Earliest December date:", december_data['Order Date'].min())
print("Latest December date:", december_data['Order Date'].max())
# Out:
# December transactions: 84
# Earliest December date: 2024-12-01 00:00:00
# Latest December date: 2024-12-03 00:00:00

# %%
best_sales_month = monthly_sales.loc[
    monthly_sales['Total_Sales'].idxmax()
]

worst_sales_month = monthly_sales.loc[
    monthly_sales['Total_Sales'].idxmin()
]

print("Best month by sales:")
print(best_sales_month)

print("\nLowest month by sales:")
print(worst_sales_month)
# Out:
# Best month by sales:
# Year_Month        2024-10
# Total_Sales       5930474
# Total_Profit    2372189.6
# Units_Sold           3308
# Transactions          743
# Name: 9, dtype: object
#
# Lowest month by sales:
# Year_Month       2024-12
# Total_Sales       584096
# Total_Profit    233638.4
# Units_Sold           343
# Transactions          84
# Name: 11, dtype: object

# %%
plt.figure(figsize=(14, 6))

plt.plot(
    monthly_sales['Year_Month'],
    monthly_sales['Total_Sales'],
    marker='o',
    label='Sales'
)

plt.plot(
    monthly_sales['Year_Month'],
    monthly_sales['Total_Profit'],
    marker='o',
    label='Profit'
)

plt.title('Monthly Sales and Profit Trend')
plt.xlabel('Month')
plt.ylabel('Amount (₹)')
plt.xticks(rotation=45)
plt.legend()

plt.show()

# %%
monthly_sales['Sales_Growth_%'] = (
    monthly_sales['Total_Sales']
    .pct_change() * 100
)

monthly_sales['Profit_Growth_%'] = (
    monthly_sales['Total_Profit']
    .pct_change() * 100
)

monthly_sales
# Out:
#    Year_Month  Total_Sales  Total_Profit  Units_Sold  Transactions  \
# 0     2024-01      5761931     2304772.4        3222           706
# 1     2024-02      5444087     2177634.8        3097           689
# 2     2024-03      5652839     2261135.6        3295           733
# 3     2024-04      5661436     2264574.4        3358           719
# 4     2024-05      5612938     2245175.2        3174           721
# 5     2024-06      5425085     2170034.0        3144           695
# 6     2024-07      5530078     2212031.2        3195           697
# 7     2024-08      5796433     2318573.2        3260           724
# 8     2024-09      5431190     2172476.0        3089           659
# 9     2024-10      5930474     2372189.6        3308           743
# 10    2024-11      5782246     2312898.4        3214           729
# 11    2024-12       584096      233638.4         343            84
#
#     Sales_Growth_%  Profit_Growth_%
# 0              NaN              NaN
# ...

# %%
highest_sales_growth = monthly_sales.loc[
    monthly_sales['Sales_Growth_%'].idxmax()
]

print("Highest Sales Growth:")
print(highest_sales_growth)
# Out:
# Highest Sales Growth:
# Year_Month           2024-10
# Total_Sales          5930474
# Total_Profit       2372189.6
# Units_Sold              3308
# Transactions             743
# Sales_Growth_%      9.192902
# Profit_Growth_%     9.192902
# Name: 9, dtype: object

# %%
lowest_sales_growth = monthly_sales.loc[
    monthly_sales['Sales_Growth_%'].idxmin()
]

print("Largest Sales Decline:")
print(lowest_sales_growth)
# Out:
# Largest Sales Decline:
# Year_Month           2024-12
# Total_Sales           584096
# Total_Profit        233638.4
# Units_Sold               343
# Transactions              84
# Sales_Growth_%    -89.898458
# Profit_Growth_%   -89.898458
# Name: 11, dtype: object

# %%
complete_months = df[
    df['Order Date'] < '2024-12-01'
].copy()

print("Rows in complete-month dataset:", len(complete_months))
# Out:
# Rows in complete-month dataset: 7815

# %%
complete_months['Year_Month'] = (
    complete_months['Order Date']
    .dt.to_period('M')
    .astype(str)
)

monthly_complete = complete_months.groupby('Year_Month').agg(
    Total_Sales=('Sales', 'sum'),
    Total_Profit=('Sales Profit', 'sum'),
    Units_Sold=('Quantity', 'sum'),
    Transactions=('Order ID', 'count')
).reset_index()

monthly_complete
# Out:
#    Year_Month  Total_Sales  Total_Profit  Units_Sold  Transactions
# 0     2024-01      5761931     2304772.4        3222           706
# 1     2024-02      5444087     2177634.8        3097           689
# 2     2024-03      5652839     2261135.6        3295           733
# 3     2024-04      5661436     2264574.4        3358           719
# 4     2024-05      5612938     2245175.2        3174           721
# 5     2024-06      5425085     2170034.0        3144           695
# 6     2024-07      5530078     2212031.2        3195           697
# 7     2024-08      5796433     2318573.2        3260           724
# 8     2024-09      5431190     2172476.0        3089           659
# 9     2024-10      5930474     2372189.6        3308           743
# 10    2024-11      5782246     2312898.4        3214           729

# %%
best_month = monthly_complete.loc[
    monthly_complete['Total_Sales'].idxmax()
]

print("Best Complete Month:")
print(best_month)
# Out:
# Best Complete Month:
# Year_Month        2024-10
# Total_Sales       5930474
# Total_Profit    2372189.6
# Units_Sold           3308
# Transactions          743
# Name: 9, dtype: object

# %%
worst_month = monthly_complete.loc[
    monthly_complete['Total_Sales'].idxmin()
]

print("Lowest Complete Month:")
print(worst_month)
# Out:
# Lowest Complete Month:
# Year_Month        2024-06
# Total_Sales       5425085
# Total_Profit    2170034.0
# Units_Sold           3144
# Transactions          695
# Name: 5, dtype: object

# %%
monthly_complete['Sales_Growth_%'] = (
    monthly_complete['Total_Sales']
    .pct_change() * 100
)

monthly_complete['Profit_Growth_%'] = (
    monthly_complete['Total_Profit']
    .pct_change() * 100
)

monthly_complete
# Out:
#    Year_Month  Total_Sales  Total_Profit  Units_Sold  Transactions  \
# 0     2024-01      5761931     2304772.4        3222           706
# 1     2024-02      5444087     2177634.8        3097           689
# 2     2024-03      5652839     2261135.6        3295           733
# 3     2024-04      5661436     2264574.4        3358           719
# 4     2024-05      5612938     2245175.2        3174           721
# 5     2024-06      5425085     2170034.0        3144           695
# 6     2024-07      5530078     2212031.2        3195           697
# 7     2024-08      5796433     2318573.2        3260           724
# 8     2024-09      5431190     2172476.0        3089           659
# 9     2024-10      5930474     2372189.6        3308           743
# 10    2024-11      5782246     2312898.4        3214           729
#
#     Sales_Growth_%  Profit_Growth_%
# 0              NaN              NaN
# 1        -5.516276        -5.516276
# 2         3.834472         3.834472
# ...

# %%
highest_growth = monthly_complete.loc[
    monthly_complete['Sales_Growth_%'].idxmax()
]

print("Highest Month-over-Month Sales Growth:")
print(highest_growth)
# Out:
# Highest Month-over-Month Sales Growth:
# Year_Month           2024-10
# Total_Sales          5930474
# Total_Profit       2372189.6
# Units_Sold              3308
# Transactions             743
# Sales_Growth_%      9.192902
# Profit_Growth_%     9.192902
# Name: 9, dtype: object

# %%
largest_decline = monthly_complete.loc[
    monthly_complete['Sales_Growth_%'].idxmin()
]

print("Largest Month-over-Month Sales Decline:")
print(largest_decline)
# Out:
# Largest Month-over-Month Sales Decline:
# Year_Month           2024-09
# Total_Sales          5431190
# Total_Profit       2172476.0
# Units_Sold              3089
# Transactions             659
# Sales_Growth_%     -6.301168
# Profit_Growth_%    -6.301168
# Name: 8, dtype: object

# %%
plt.figure(figsize=(14, 6))

plt.plot(
    monthly_complete['Year_Month'],
    monthly_complete['Total_Sales'],
    marker='o',
    label='Sales'
)

plt.plot(
    monthly_complete['Year_Month'],
    monthly_complete['Total_Profit'],
    marker='o',
    label='Profit'
)

plt.title('Monthly Sales and Profit Trend - 2024')
plt.xlabel('Month')
plt.ylabel('Amount (₹)')
plt.xticks(rotation=45)
plt.legend()

plt.show()

# %%
category_state = df.groupby(
    ['State', 'Category']
).agg(
    Total_Sales=('Sales', 'sum'),
    Total_Profit=('Sales Profit', 'sum'),
    Units_Sold=('Quantity', 'sum'),
    Transactions=('Order ID', 'count')
).reset_index()

category_state.head(20)
# Out:
#             State Category  Total_Sales  Total_Profit  Units_Sold  \
# 0           Delhi     Kids      2757269     1102907.6        1556
# 1           Delhi      Men      2494984      997993.6        1442
# 2           Delhi    Women      2726036     1090414.4        1601
# 3         Gujarat     Kids      2540553     1016221.2        1478
# 4         Gujarat      Men      2536962     1014784.8        1479
# 5         Gujarat    Women      2548787     1019514.8        1457
# 6       Karnataka     Kids      2638340     1055336.0        1510
# 7       Karnataka      Men      2433073      973229.2        1364
# 8       Karnataka    Women      2515456     1006182.4        1453
# 9     Maharashtra     Kids      2606123     1042449.2        1561
# 10    Maharashtra      Men      2544649     1017859.6        1504
# 11    Maharashtra    Women      2573442     1029376.8        1481
# 12      Rajasthan     Kids      2812791     1125116.4        1521
# ...

# %%
best_category_by_state = (
    category_state
    .loc[
        category_state.groupby('State')['Total_Sales'].idxmax()
    ]
    .sort_values('Total_Sales', ascending=False)
)

best_category_by_state
# Out:
#             State Category  Total_Sales  Total_Profit  Units_Sold  \
# 12      Rajasthan     Kids      2812791     1125116.4        1521
# 19  Uttar Pradesh      Men      2785059     1114023.6        1541
# 22    West Bengal      Men      2772627     1109050.8        1565
# 0           Delhi     Kids      2757269     1102907.6        1556
# 17     Tamil Nadu    Women      2666327     1066530.8        1526
# 6       Karnataka     Kids      2638340     1055336.0        1510
# 9     Maharashtra     Kids      2606123     1042449.2        1561
# 5         Gujarat    Women      2548787     1019514.8        1457
#
#     Transactions
# 12           342
# 19           336
# 22           332
# 0            346
# 17           316
# 6            335
# 9            334
# 5            313

# %%
category_city = df.groupby(
    ['City', 'Category']
).agg(
    Total_Sales=('Sales', 'sum'),
    Total_Profit=('Sales Profit', 'sum'),
    Units_Sold=('Quantity', 'sum'),
    Transactions=('Order ID', 'count')
).reset_index()

# %%
best_category_by_city = (
    category_city
    .loc[
        category_city.groupby('City')['Total_Sales'].idxmax()
    ]
    .sort_values('Total_Sales', ascending=False)
)

best_category_by_city.head(15)
# Out:
#               City Category  Total_Sales  Total_Profit  Units_Sold  \
# 38       Hyderabad    Women       684543      273817.2         386
# 24      Coimbatore     Kids       655510      262204.0         349
# 60         Kolkata     Kids       648668      259467.2         392
# 48           Jammu     Kids       646107      258442.8         347
# 113          Surat    Women       624642      249856.8         332
# 13          Bhopal      Men       622020      248808.0         336
# 125  Visakhapatnam    Women       613372      245348.8         341
# 75          Mysuru     Kids       605685      242274.0         319
# 105         Satara     Kids       604495      241798.0         333
# 45           Jalna     Kids       602094      240837.6         363
# 100         Rajkot      Men       596352      238540.8         348
# 21    Chhattisgarh     Kids       590881      236352.4         318
# 2             Agra    Women       584904      233961.6         310
# ...

# %%
pivot_state_category = category_state.pivot(
    index='State',
    columns='Category',
    values='Total_Sales'
)

plt.figure(figsize=(10, 6))

sns.heatmap(
    pivot_state_category,
    annot=True,
    fmt='.0f'
)

plt.title('Sales by State and Category')
plt.xlabel('Category')
plt.ylabel('State')

plt.show()

# %%
total_sales = df['Sales'].sum()
total_transactions = df['Order ID'].count()

aov = total_sales / total_transactions

print("Average Order Value:", round(aov, 2))
# Out:
# Average Order Value: 7926.68

# %%
average_units_per_transaction = (
    df['Quantity'].sum() /
    df['Order ID'].count()
)

print(
    "Average Units per Transaction:",
    round(average_units_per_transaction, 2)
)
# Out:
# Average Units per Transaction: 4.52

# %%
total_sales = df['Sales'].sum()
total_profit = df['Sales Profit'].sum()
total_units = df['Quantity'].sum()
total_transactions = df['Order ID'].count()
average_price = df['Price'].mean()

profit_margin = (
    total_profit / total_sales
) * 100

aov = total_sales / total_transactions

avg_units_transaction = (
    total_units / total_transactions
)

kpi_summary = pd.DataFrame({
    'KPI': [
        'Total Sales',
        'Total Profit',
        'Total Units Sold',
        'Total Transactions',
        'Average Price',
        'Profit Margin %',
        'Average Order Value',
        'Average Units per Transaction'
    ],
    'Value': [
        total_sales,
        total_profit,
        total_units,
        total_transactions,
        average_price,
        profit_margin,
        aov,
        avg_units_transaction
    ]
})

kpi_summary
# Out:
#                              KPI         Value
# 0                    Total Sales  6.261283e+07
# 1                   Total Profit  2.504513e+07
# 2               Total Units Sold  3.569900e+04
# 3             Total Transactions  7.899000e+03
# 4                  Average Price  1.761113e+03
# 5                Profit Margin %  4.000000e+01
# 6            Average Order Value  7.926678e+03
# 7  Average Units per Transaction  4.519433e+00

# %%
category_state[
    category_state['State'] == 'West Bengal'
].sort_values('Total_Sales', ascending=False)
# Out:
#           State Category  Total_Sales  Total_Profit  Units_Sold  Transactions
# 22  West Bengal      Men      2772627     1109050.8        1565           332
# 21  West Bengal     Kids      2681452     1072580.8        1478           328
# 23  West Bengal    Women      2651708     1060683.2        1486           322

# %%
best_state_category = category_state.sort_values(
    'Total_Sales',
    ascending=False
).head(10)

best_state_category
# Out:
#             State Category  Total_Sales  Total_Profit  Units_Sold  \
# 12      Rajasthan     Kids      2812791     1125116.4        1521
# 19  Uttar Pradesh      Men      2785059     1114023.6        1541
# 22    West Bengal      Men      2772627     1109050.8        1565
# 0           Delhi     Kids      2757269     1102907.6        1556
# 2           Delhi    Women      2726036     1090414.4        1601
# 20  Uttar Pradesh    Women      2690728     1076291.2        1506
# 21    West Bengal     Kids      2681452     1072580.8        1478
# 17     Tamil Nadu    Women      2666327     1066530.8        1526
# 23    West Bengal    Women      2651708     1060683.2        1486
# 6       Karnataka     Kids      2638340     1055336.0        1510
#
#     Transactions
# 12           342
# 19           336
# 22           332
# 0            346
# 2            348
# 20           340
# 21           328
# 17           316
# 23           322
# 6            335

# %%
best_state_category
# Out:
#             State Category  Total_Sales  Total_Profit  Units_Sold  \
# 12      Rajasthan     Kids      2812791     1125116.4        1521
# 19  Uttar Pradesh      Men      2785059     1114023.6        1541
# 22    West Bengal      Men      2772627     1109050.8        1565
# 0           Delhi     Kids      2757269     1102907.6        1556
# 2           Delhi    Women      2726036     1090414.4        1601
# 20  Uttar Pradesh    Women      2690728     1076291.2        1506
# 21    West Bengal     Kids      2681452     1072580.8        1478
# 17     Tamil Nadu    Women      2666327     1066530.8        1526
# 23    West Bengal    Women      2651708     1060683.2        1486
# 6       Karnataka     Kids      2638340     1055336.0        1510
#
#     Transactions
# 12           342
# 19           336
# 22           332
# 0            346
# 2            348
# 20           340
# 21           328
# 17           316
# 23           322
# 6            335

# %%
kpi_summary
# Out:
#                              KPI         Value
# 0                    Total Sales  6.261283e+07
# 1                   Total Profit  2.504513e+07
# 2               Total Units Sold  3.569900e+04
# 3             Total Transactions  7.899000e+03
# 4                  Average Price  1.761113e+03
# 5                Profit Margin %  4.000000e+01
# 6            Average Order Value  7.926678e+03
# 7  Average Units per Transaction  4.519433e+00

# %%
final_kpi = pd.DataFrame({
    'Metric': [
        'Total Sales',
        'Total Profit',
        'Total Units Sold',
        'Total Transactions',
        'Average Price',
        'Profit Margin',
        'Average Order Value',
        'Average Units per Transaction'
    ],
    'Value': [
        total_sales,
        total_profit,
        total_units,
        total_transactions,
        average_price,
        profit_margin,
        aov,
        avg_units_transaction
    ]
})

final_kpi
# Out:
#                           Metric         Value
# 0                    Total Sales  6.261283e+07
# 1                   Total Profit  2.504513e+07
# 2               Total Units Sold  3.569900e+04
# 3             Total Transactions  7.899000e+03
# 4                  Average Price  1.761113e+03
# 5                  Profit Margin  4.000000e+01
# 6            Average Order Value  7.926678e+03
# 7  Average Units per Transaction  4.519433e+00

# %%
category_analysis = df.groupby('Category').agg(
    Total_Sales=('Sales', 'sum'),
    Total_Profit=('Sales Profit', 'sum'),
    Units_Sold=('Quantity', 'sum')
).reset_index()

plt.figure(figsize=(8, 5))

sns.barplot(
    data=category_analysis,
    x='Category',
    y='Total_Sales'
)

plt.title('Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Sales (₹)')

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.barplot(
    data=state_analysis,
    x='Total_Sales',
    y='State'
)

plt.title('Sales by State')
plt.xlabel('Total Sales (₹)')
plt.ylabel('State')

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.barplot(
    data=top_10_sales,
    x='Total_Sales',
    y='Product ID'
)

plt.title('Top 10 Products by Sales')
plt.xlabel('Total Sales (₹)')
plt.ylabel('Product ID')

plt.show()

# %%
plt.figure(figsize=(12, 6))

plt.plot(
    monthly_complete['Year_Month'],
    monthly_complete['Total_Sales'],
    marker='o'
)

plt.title('Monthly Sales Trend - 2024')
plt.xlabel('Month')
plt.ylabel('Sales (₹)')
plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.heatmap(
    pivot_state_category,
    annot=True,
    fmt='.0f'
)

plt.title('Sales by State and Category')
plt.xlabel('Category')
plt.ylabel('State')

plt.show()

# %%
df.to_csv(
    'Zudio_Cleaned_Sales_Data.csv',
    index=False
)

print("File saved successfully!")
# Out:
# File saved successfully!

# %%
import os

print(os.path.exists('Zudio_Cleaned_Sales_Data.csv'))
# Out:
# True

# %%
final_kpi
# Out:
#                           Metric         Value
# 0                    Total Sales  6.261283e+07
# 1                   Total Profit  2.504513e+07
# 2               Total Units Sold  3.569900e+04
# 3             Total Transactions  7.899000e+03
# 4                  Average Price  1.761113e+03
# 5                  Profit Margin  4.000000e+01
# 6            Average Order Value  7.926678e+03
# 7  Average Units per Transaction  4.519433e+00

# %%
df.to_csv('Zudio_Cleaned_Sales_Data.csv', index=False)

print("File saved successfully!")
# Out:
# File saved successfully!

# %%
import os

print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Pragya Prasad\desktop\python-program
